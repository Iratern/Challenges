# %%
# %load_ext sql

# %%
# %sql ibm_db_sa://bxz77733:56tmh3jr3nz-gqf0@dashdb-txn-sbox-yp-dal09-04.services.dal.bluemix.net:50000/BLUDB
# Out:
# DB2/LINUXX8664

# %%
# %%sql
# select * from shopify_data limit 10
# Out:
#  * ibm_db_sa://bxz77733:***@dashdb-txn-sbox-yp-dal09-04.services.dal.bluemix.net:50000/BLUDB
# Done.
# [(1, 53, 746, 224, 2, 'cash', datetime.datetime(2017, 3, 13, 12, 36, 56)),
#  (2, 92, 925, 90, 1, 'cash', datetime.datetime(2017, 3, 3, 17, 38, 52)),
#  (3, 44, 861, 144, 1, 'cash', datetime.datetime(2017, 3, 14, 4, 23, 56)),
#  (4, 18, 935, 156, 1, 'credit_card', datetime.datetime(2017, 3, 26, 12, 43, 37)),
#  (5, 18, 883, 156, 1, 'credit_card', datetime.datetime(2017, 3, 1, 4, 35, 11)),
#  (6, 58, 882, 138, 1, 'credit_card', datetime.datetime(2017, 3, 14, 15, 25, 1)),
#  (7, 87, 915, 149, 1, 'cash', datetime.datetime(2017, 3, 1, 21, 37, 57)),
#  (8, 22, 761, 292, 2, 'cash', datetime.datetime(2017, 3, 8, 2, 5, 38)),
#  (9, 64, 914, 266, 2, 'debit', datetime.datetime(2017, 3, 17, 20, 56, 50)),
#  (10, 52, 788, 146, 1, 'credit_card', datetime.datetime(2017, 3, 30, 21, 8, 26))]

# %%
# %%sql
# select * from shopify_data where "shop_id" = 78
# Out:
#  * ibm_db_sa://bxz77733:***@dashdb-txn-sbox-yp-dal09-04.services.dal.bluemix.net:50000/BLUDB
# Done.
# [(161, 78, 990, 25725, 1, 'credit_card', datetime.datetime(2017, 3, 12, 5, 56, 57)),
#  (491, 78, 936, 51450, 2, 'debit', datetime.datetime(2017, 3, 26, 17, 8, 19)),
#  (494, 78, 983, 51450, 2, 'cash', datetime.datetime(2017, 3, 16, 21, 39, 35)),
#  (512, 78, 967, 51450, 2, 'cash', datetime.datetime(2017, 3, 9, 7, 23, 14)),
#  (618, 78, 760, 51450, 2, 'cash', datetime.datetime(2017, 3, 18, 11, 18, 42)),
#  (692, 78, 878, 154350, 6, 'debit', datetime.datetime(2017, 3, 27, 22, 51, 43)),
#  (1057, 78, 800, 25725, 1, 'debit', datetime.datetime(2017, 3, 15, 10, 16, 45)),
#  (1194, 78, 944, 25725, 1, 'debit', datetime.datetime(2017, 3, 16, 16, 38, 26)),
#  (1205, 78, 970, 25725, 1, 'credit_card', datetime.datetime(2017, 3, 17, 22, 32, 21)),
#  (1260, 78, 775, 77175, 3, 'credit_card', datetime.datetime(2017, 3, 27, 9, 27, 20)),
# ...

# %%
# %%sql
# select * from shopify_data where "user_id" = 607
# Out:
#  * ibm_db_sa://bxz77733:***@dashdb-txn-sbox-yp-dal09-04.services.dal.bluemix.net:50000/BLUDB
# Done.
# [(16, 42, 607, 704000, 2000, 'credit_card', datetime.datetime(2017, 3, 7, 4, 0)),
#  (61, 42, 607, 704000, 2000, 'credit_card', datetime.datetime(2017, 3, 4, 4, 0)),
#  (521, 42, 607, 704000, 2000, 'credit_card', datetime.datetime(2017, 3, 2, 4, 0)),
#  (1105, 42, 607, 704000, 2000, 'credit_card', datetime.datetime(2017, 3, 24, 4, 0)),
#  (1363, 42, 607, 704000, 2000, 'credit_card', datetime.datetime(2017, 3, 15, 4, 0)),
#  (1437, 42, 607, 704000, 2000, 'credit_card', datetime.datetime(2017, 3, 11, 4, 0)),
#  (1563, 42, 607, 704000, 2000, 'credit_card', datetime.datetime(2017, 3, 19, 4, 0)),
#  (1603, 42, 607, 704000, 2000, 'credit_card', datetime.datetime(2017, 3, 17, 4, 0)),
#  (2154, 42, 607, 704000, 2000, 'credit_card', datetime.datetime(2017, 3, 12, 4, 0)),
#  (2298, 42, 607, 704000, 2000, 'credit_card', datetime.datetime(2017, 3, 7, 4, 0)),
# ...

# %%
# %%sql
# select count(*) from shopify_data where "shop_id" = 78
# Out:
#  * ibm_db_sa://bxz77733:***@dashdb-txn-sbox-yp-dal09-04.services.dal.bluemix.net:50000/BLUDB
# Done.
# [(Decimal('46'),)]

# %%
# %%sql
# select count(*) from shopify_data where "user_id" = 607
# Out:
#  * ibm_db_sa://bxz77733:***@dashdb-txn-sbox-yp-dal09-04.services.dal.bluemix.net:50000/BLUDB
# Done.
# [(Decimal('17'),)]

# %%
# %%sql
# select "user_id", count(*) as number_of_purchases from shopify_data group by "user_id"
# Out:
#  * ibm_db_sa://bxz77733:***@dashdb-txn-sbox-yp-dal09-04.services.dal.bluemix.net:50000/BLUDB
# Done.
# [(607, Decimal('17')),
#  (700, Decimal('16')),
#  (701, Decimal('13')),
#  (702, Decimal('13')),
#  (703, Decimal('16')),
#  (704, Decimal('14')),
#  (705, Decimal('22')),
#  (706, Decimal('13')),
#  (707, Decimal('18')),
#  (708, Decimal('14')),
#  (709, Decimal('14')),
#  (710, Decimal('16')),
#  (711, Decimal('22')),
#  (712, Decimal('23')),
#  (713, Decimal('19')),
#  (714, Decimal('13')),
#  (715, Decimal('12')),
#  (716, Decimal('14')),
#  (717, Decimal('7')),
#  (718, Decimal('28')),
#  (719, Decimal('9')),
#  (720, Decimal('15')),
#  (721, Decimal('19')),
#  (722, Decimal('13')),
#  (723, Decimal('23')),
#  (724, Decimal('17')),
#  (725, Decimal('19')),
#  (726, Decimal('18')),
#  (727, Decimal('25')),
#  (728, Decimal('16')),
#  (729, Decimal('10')),
#  (730, Decimal('15')),
#  (731, Decimal('20')),
#  (732, Decimal('13')),
#  (733, Decimal('17')),
# ...

# %%
# %%sql
# select AVG("order_amount"/"total_items") as val_per_item_all from shopify_data
#
# --average per item value
# Out:
#  * ibm_db_sa://bxz77733:***@dashdb-txn-sbox-yp-dal09-04.services.dal.bluemix.net:50000/BLUDB
# Done.
# [(Decimal('387.742800'),)]

# %%
# %%sql
# select avg("order_amount"/"total_items") as value_per_item from shopify_data where "shop_id" != 78
#
# --- average per item value where shop ID 78 (the very expensive sneaker) is excluded
# Out:
#  * ibm_db_sa://bxz77733:***@dashdb-txn-sbox-yp-dal09-04.services.dal.bluemix.net:50000/BLUDB
# Done.
# [(Decimal('152.475575'),)]

# %%
# %%sql
# select avg("order_amount") as average_order_value from shopify_data where "user_id" != 607 AND "shop_id" != 78
#
# --- average order value exluding both non-representative shop and users
# Out:
#  * ibm_db_sa://bxz77733:***@dashdb-txn-sbox-yp-dal09-04.services.dal.bluemix.net:50000/BLUDB
# Done.
# [(Decimal('302.580514'),)]

# %%
# %%sql
# select avg("order_amount") as average_order_value from shopify_data where "user_id" != 607
#
# --average order value exluding user 607 who purchases huge orders
# Out:
#  * ibm_db_sa://bxz77733:***@dashdb-txn-sbox-yp-dal09-04.services.dal.bluemix.net:50000/BLUDB
# Done.
# [(Decimal('754.091912'),)]

# %%
# %%sql
# select "payment_method", avg("order_amount") as average_order_value from shopify_data where "user_id" != 607 AND "shop_id" != 78 group by "payment_method"
# Out:
#  * ibm_db_sa://bxz77733:***@dashdb-txn-sbox-yp-dal09-04.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('cash', Decimal('297.974619')),
#  ('credit_card', Decimal('301.415105')),
#  ('debit', Decimal('308.176043'))]

# %%
# %%sql
# select "payment_method", avg("order_amount"/"total_items") as average_order_value from shopify_data where "user_id" != 607 and "shop_id" != 78 group by "payment_method"
# Out:
#  * ibm_db_sa://bxz77733:***@dashdb-txn-sbox-yp-dal09-04.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('cash', Decimal('151.074873')),
#  ('credit_card', Decimal('151.732435')),
#  ('debit', Decimal('152.526920'))]
